# %% [markdown]
# # Linear Regression on Boston Dataset for the Data Analytics Session
# by Rathachai C.

# %% [markdown]
# ## 1) To load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ---

# %% [markdown]
# ## 2) To load data and check

# %%
boston = pd.read_csv('https://rathachai.github.io/DA101/data/boston.csv')

# %%
boston
# Out:
#         crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null int64
# ptratio    506 non-null float64
# black      506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              crim          zn       indus  ...       black       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 3) To do data exploration

# %%
sns.pairplot(boston)

# %%
sns.pairplot(boston, x_vars=boston.columns, y_vars=["medv"])

# %%
sns.distplot(boston['medv'])

# %% [markdown]
# ---

# %% [markdown]
# ## 4) To do feature selection

# %% [markdown]
# ### 4.1) to check the correlation

# %%
boston.corr()
# Out:
#              crim        zn     indus  ...     black     lstat      medv
# crim     1.000000 -0.200469  0.406583  ... -0.385064  0.455621 -0.388305
# zn      -0.200469  1.000000 -0.533828  ...  0.175520 -0.412995  0.360445
# indus    0.406583 -0.533828  1.000000  ... -0.356977  0.603800 -0.483725
# chas    -0.055892 -0.042697  0.062938  ...  0.048788 -0.053929  0.175260
# nox      0.420972 -0.516604  0.763651  ... -0.380051  0.590879 -0.427321
# rm      -0.219247  0.311991 -0.391676  ...  0.128069 -0.613808  0.695360
# age      0.352734 -0.569537  0.644779  ... -0.273534  0.602339 -0.376955
# dis     -0.379670  0.664408 -0.708027  ...  0.291512 -0.496996  0.249929
# rad      0.625505 -0.311948  0.595129  ... -0.444413  0.488676 -0.381626
# tax      0.582764 -0.314563  0.720760  ... -0.441808  0.543993 -0.468536
# ptratio  0.289946 -0.391679  0.383248  ... -0.177383  0.374044 -0.507787
# black   -0.385064  0.175520 -0.356977  ...  1.000000 -0.366087  0.333461
# lstat    0.455621 -0.412995  0.603800  ... -0.366087  1.000000 -0.737663
# medv    -0.388305  0.360445 -0.483725  ...  0.333461 -0.737663  1.000000
#
# [14 rows x 14 columns]

# %%
sns.heatmap(boston.corr())

# %%
boston.corr().sort_values("medv")["medv"]
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# black      0.333461
# zn         0.360445
# rm         0.695360
# medv       1.000000
# Name: medv, dtype: float64

# %%
sns.pairplot(boston, x_vars=["lstat","rm"], y_vars=["medv"])

# %% [markdown]
# ### 4.2) to select data

# %%
X = boston[["lstat","rm"]]
y = boston["medv"]

# %%
X
# Out:
#      lstat     rm
# 0     4.98  6.575
# 1     9.14  6.421
# 2     4.03  7.185
# 3     2.94  6.998
# 4     5.33  7.147
# ..     ...    ...
# 501   9.67  6.593
# 502   9.08  6.120
# 503   5.64  6.976
# 504   6.48  6.794
# 505   7.88  6.030
#
# [506 rows x 2 columns]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## 5) To create a Linear Regression Model

# %% [markdown]
# ### 5.1) to split train and test datasets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %% [markdown]
# ## 5.2) to train and create a linear regression model

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([-0.70994265,  4.04113651])

# %%
lm.intercept_
# Out:
# 5.7586387935200385

# %% [markdown]
# ---

# %% [markdown]
# ## 6) To evaluate the model

# %% [markdown]
# ### 6.1) to predict from the test set

# %%
y_pred = lm.predict(X_test)

# %%
y_pred
# Out:
# array([35.47405915, 30.85664713, 20.0761843 , 19.69947079, 29.34298185,
#        30.08040004, 37.73052039, 10.1308903 , 30.55761284,  8.67193517,
#        27.86195528, 14.29159811, 19.50785006, 24.0062328 , 23.61300587,
#        19.80972804,  8.27995474, 31.12076738, 27.81004958, 26.6476192 ,
#        12.25462619, 18.40369273, 24.5323439 , 31.36672795, 32.11728675,
#        20.94569697, 27.22428466, 20.82117036, 23.19602509, 30.45404545,
#        23.93882596, 20.89407454, 33.67334871, 35.5331446 , 23.60311854,
#        21.84789741, 19.25579434, 21.03876757,  5.59053515, 28.24814348,
#        21.65784443, 25.79244458, 34.82583106, 12.73806041, 19.00005436,
#        25.7085145 , 30.31917107, 17.51012821, 27.38113545, 28.75183426,
#        32.13529252, 37.48422075, 19.2558434 , 21.84594153, 31.93313576,
#        -4.47566061, 18.57637391, 16.09518168, 17.84513789, 18.81579362,
#        31.43290302,  1.61197647, 15.09433426, 21.75536083, 12.26967851,
#        26.25570437, 24.01778784, 19.99277663, 17.24228627, 20.49071933,
#        22.77791246, 26.46609731, 19.79243165, 22.91102103, 26.97756564,
#        19.95637206, 34.79450934,  5.70340188, 29.34843992, 16.9655331 ,
#        18.12626634, 21.35440051, 28.42792408, 18.58299018,  7.26569507,
#        24.13400286, 21.62353002, 28.42320973, 22.67634021, 23.18233084,
#        11.37572406,  9.09888851, 26.08337697, 27.38119123,  6.07781063,
#        34.24553403,  4.70067089, 30.19006439, 12.40993557, 23.30033129,
#        31.98434371, 21.92673482, 25.88285174, 26.34924832, 21.79391626,
#        22.90876043, 26.61539495, 31.63801323, 36.22351063, 30.49875179,
#        21.77787618, 36.28161814, 25.57616437, 21.26247155, 31.12292314,
#        25.82058844, 27.871235  , 29.33675552, 23.41421703, 25.38524811,
#        20.65086935, 20.64898215, 22.93738745, 30.56254179, 27.45684407,
#        23.35862887, 20.5134002 ,  3.74094113, 15.60503616, 24.01255907,
#        26.25301948, 30.96761376, 23.7754294 , 20.05829319, 25.68784038,
#        23.44907528, 25.78256215, 25.55120999, 34.03583884, 24.70458607,
#        16.02696734, 34.30376601, 30.3876607 , 18.61569758, 29.22678155,
#        23.32141498, 23.93523363, 24.86162202, 19.99144981, 26.84879803,
#        19.55018787, 16.89303177, 36.1804947 , 32.00982232, 23.75509925,
#        20.93621247, 21.58607701,  9.71521671, 23.75032111, 27.33768051,
#        19.89126996, 26.44939382, 37.29778463, 29.61852285, 25.53714542,
#        19.89074084, 17.88160315, 28.56803214, 19.34832601, 14.83591485,
#        21.46309181, 30.65864125, 30.99380174, 25.07136137,  0.0602898 ,
#        18.88838508, 29.68101056, 19.39295386, 28.29400802, 28.14067905,
#        19.96152541, 24.46833931, 24.04411501, 34.00597513, 23.59344397,
#        33.70250976, 17.08526994, 19.66437832, 21.47186202, 17.61949274,
#        26.9197972 , 30.3900752 ,  6.61039699, 18.14570868, 19.40584062,
#        25.43601706, 25.76984093, 18.36689822, 22.18230927, 27.11105743,
#        17.03568861, 20.88969434, 26.69173264])

# %% [markdown]
# ### 6.2 to evaluate with some evaluation methods

# %%
plt.scatter(y_test,y_pred)

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print("RMSE = ", rmse)
# Out:
# RMSE =  6.238742389666769

# %%
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("MAPE = ", mape, "%")
# Out:
# MAPE =  21.16845297991399 %

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#
#
# 1.   apply feature scaling (hint: https://scikit-learn.org/stable/modules/preprocessing.html)
# 2.   work with 5-fold cross-validation  (hint: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)
# 3.   evaluate using RMSE

# %% [markdown]
# ### do your exerciese here

# %%
# run your code here
